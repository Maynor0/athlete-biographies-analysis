# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bios = pd.read_csv("bios.csv")

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  str
#  2   born_date     143693 non-null  str
#  3   born_city     110908 non-null  str
#  4   born_region   110908 non-null  str
#  5   born_country  110908 non-null  str
#  6   NOC           145499 non-null  str
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   str
# dtypes: float64(2), int64(1), str(7)
# memory usage: 18.5 MB

# %%
bios.isna().sum()
# Out:
# athlete_id           0
# name                 0
# born_date         1807
# born_city        34592
# born_region      34592
# born_country     34592
# NOC                  1
# height_cm        38849
# weight_kg        43430
# died_date       111560
# dtype: int64

# %%
bios_new = bios.copy()

# %%
bios_new["born_date"]= pd.to_datetime(bios["born_date"], errors="coerce")
bios_new["died_date"]= pd.to_datetime(bios["died_date"], errors="coerce")

# %%
for col in ["born_city", "born_region", "born_country", "NOC", "name"]:
    bios_new[col] = bios_new[col].fillna("Unknown").astype("string").str.strip()

# %%
bios_new.head()
# Out:
#    athlete_id                   name  born_date    born_city  \
# 0           1  Jean-François Blanchy 1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch 1969-04-01       Meulan
# 2           3           Jean Borotra 1898-08-13     Biarritz
# 3           4        Jacques Brugnon 1895-05-11  Paris VIIIe
# 4           5           Albert Canet 1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  died_date
# 0               Gironde          FRA  France        NaN        NaN 1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0        NaT
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0 1994-07-17
# 3                 Paris          FRA  France      168.0       64.0 1978-03-20
# 4               England          GBR  France        NaN        NaN 1930-07-25

# %%
import unicodedata
def quitar_tildes(texto):
    if isinstance(texto, str):
        texto = unicodedata.normalize("NFD", texto)
        return "".join (c for c in texto if not unicodedata.combining(c))
    return texto

# %%
cols =["name","born_city","born_region","NOC"]

for c in cols:
    bios_new[c] = bios_new[c].astype("string").str.strip().map(quitar_tildes)

# %%
bios_new
# Out:
#         athlete_id                   name  born_date        born_city  \
# 0                1  Jean-Francois Blanchy 1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch 1969-04-01           Meulan
# 2                3           Jean Borotra 1898-08-13         Biarritz
# 3                4        Jacques Brugnon 1895-05-11      Paris VIIIe
# 4                5           Albert Canet 1878-04-17       Wandsworth
# ...            ...                    ...        ...              ...
# 145495      149222      Polina Luchnikova 2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva 1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova 1998-05-08           Kotlas
# 145498      149225         Andre Foussard 1899-05-19            Niort
# 145499      149814          Bill Phillips 1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrenees-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sevres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#         died_date
# 0      1960-10-02
# 1             NaT
# 2      1994-07-17
# 3      1978-03-20
# 4      1930-07-25
# ...           ...
# 145495        NaT
# 145496        NaT
# 145497        NaT
# 145498 1986-03-18
# 145499 2003-10-20
#
# [145500 rows x 10 columns]

# %%
bios_new.isna().sum()
# Out:
# athlete_id           0
# name                 0
# born_date         1807
# born_city            0
# born_region          0
# born_country         0
# NOC                  0
# height_cm        38849
# weight_kg        43430
# died_date       111560
# dtype: int64

# %%
bios_new = bios_new.rename(columns={
    "athlete_id": "ID_Atleta",
    "name": "Atleta",
    "born_date": "Fecha_Nacimiento",
    "born_city": "Ciudad_Nacimiento",
    "born_region": "Region_Nacimiento",
    "born_country": "Pais_Nacimiento",
    "height_cm": "Estatura_Cm",
    "weight_kg": "Peso_Kg",
    "died_date": "Fecha_Fallecimiento"
})

# %%
bios_new.head()
# Out:
#    ID_Atleta                 Atleta Fecha_Nacimiento Ciudad_Nacimiento  \
# 0          1  Jean-Francois Blanchy       1886-12-12          Bordeaux
# 1          2         Arnaud Boetsch       1969-04-01            Meulan
# 2          3           Jean Borotra       1898-08-13          Biarritz
# 3          4        Jacques Brugnon       1895-05-11       Paris VIIIe
# 4          5           Albert Canet       1878-04-17        Wandsworth
#
#       Region_Nacimiento Pais_Nacimiento     NOC  Estatura_Cm  Peso_Kg  \
# 0               Gironde             FRA  France          NaN      NaN
# 1              Yvelines             FRA  France        183.0     76.0
# 2  Pyrenees-Atlantiques             FRA  France        183.0     76.0
# 3                 Paris             FRA  France        168.0     64.0
# 4               England             GBR  France          NaN      NaN
#
#   Fecha_Fallecimiento
# 0          1960-10-02
# 1                 NaT
# 2          1994-07-17
# 3          1978-03-20
# 4          1930-07-25
